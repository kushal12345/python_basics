# %%
import pandas as pd

# %%
ser = pd.Series(data=[100, 200, 300, 400, 500], index=['tom', 'mom', 'bob', 'gob', 'lin'])

# %%
ser
# Out:
# tom    100
# mom    200
# bob    300
# gob    400
# lin    500
# dtype: int64

# %%
serHet = pd.Series(['lol', 100], ['first', 'second'])

# %%
serHet
# Out:
# first     lol
# second    100
# dtype: object

# %%
ser['tom']
# Out:
# 100

# %%
ser.tom
# Out:
# 100

# %%
ser.loc['tom']
# Out:
# 100

# %%
ser[['tom', 'bob']]
# Out:
# tom    100
# bob    300
# dtype: int64

# %%
ser[[4, 3, 1]]
# Out:
# lin    500
# gob    400
# mom    200
# dtype: int64

# %%
ser.iloc[0]
# Out:
# 100

# %%
'mom' in ser
# Out:
# True

# %%
'lob' in ser
# Out:
# False

# %%
ser * 2
# Out:
# tom     200
# mom     400
# bob     600
# gob     800
# lin    1000
# dtype: int64

# %%
ser[['tom', 'mom']] ** 2
# Out:
# tom    10000
# mom    40000
# dtype: int64

# %%
newesr = pd.Series(data=[200, 300], index=['first', 'second'], dtype="float32")

# %%
newesr
# Out:
# first     200.0
# second    300.0
# dtype: float32

# %%
newesr[['first', 'second']] ** 2
# Out:
# first     40000.0
# second    90000.0
# dtype: float32

# %% [markdown]
# ### DataFrames

# %%
d = {'one': pd.Series([100, 200, 300], ['apple', 'orange', 'banana'], 'float32'),
      'two': pd.Series([111, 222, 333], ['apple', 'orange', 'clock'], 'float32')}

# %%
df = pd.DataFrame(d)
df
# Out:
#           one    two
# apple   100.0  111.0
# banana  300.0    NaN
# clock     NaN  333.0
# orange  200.0  222.0

# %%
df.index
# Out:
# Index(['apple', 'banana', 'clock', 'orange'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
pd.DataFrame(d, index=['apple', 'clock'])
# Out:
#          one    two
# apple  100.0  111.0
# clock    NaN  333.0

# %%
pd.DataFrame(d, index=['apple', 'clock'], columns=['two', 'five'])
# Out:
#          two five
# apple  111.0  NaN
# clock  333.0  NaN

# %%
data = [{'alex': 1, 'joe': 2},{ 'ema': 5, 'dota': 6, 'alice': 11}]

# %%
pd.DataFrame(data)
# Out:
#    alex  alice  dota  ema  joe
# 0   1.0    NaN   NaN  NaN  2.0
# 1   NaN   11.0   6.0  5.0  NaN

# %%
pd.DataFrame(data, index=['orange', 'red'])
# Out:
#         alex  alice  dota  ema  joe
# orange   1.0    NaN   NaN  NaN  2.0
# red      NaN   11.0   6.0  5.0  NaN

# %%
pd.DataFrame(data, columns=['joe', 'dora'])
# Out:
#    joe  dora
# 0  2.0   NaN
# 1  NaN   NaN

# %%
df
# Out:
#           one    two
# apple   100.0  111.0
# banana  300.0    NaN
# clock     NaN  333.0
# orange  200.0  222.0

# %%
df['one']
# Out:
# apple     100.0
# banana    300.0
# clock       NaN
# orange    200.0
# Name: one, dtype: float32

# %%
print(df['one'])
# Out:
# apple     100.0
# banana    300.0
# clock       NaN
# orange    200.0
# Name: one, dtype: float32

# %%
df['three'] = df['one'] + df['two']

# %%
df['three']
# Out:
# apple     211.0
# banana      NaN
# clock       NaN
# orange    422.0
# Name: three, dtype: float32

# %%
df
# Out:
#           one    two  three
# apple   100.0  111.0  211.0
# banana  300.0    NaN    NaN
# clock     NaN  333.0    NaN
# orange  200.0  222.0  422.0

# %%
df['flag'] = df['one'] > 250

# %%
df
# Out:
#           one    two  three   flag
# apple   100.0  111.0  211.0  False
# banana  300.0    NaN    NaN   True
# clock     NaN  333.0    NaN  False
# orange  200.0  222.0  422.0  False

# %%
# poo
three = df.pop('three')

# %%
three
# Out:
# apple     211.0
# banana      NaN
# clock       NaN
# orange    422.0
# Name: three, dtype: float32

# %%
df
# Out:
#           one    two   flag
# apple   100.0  111.0  False
# banana  300.0    NaN   True
# clock     NaN  333.0  False
# orange  200.0  222.0  False

# %%
df.insert(1, 'copy_one', df['one'])

# %%
df
# Out:
#           one  copy_one    two   flag
# apple   100.0     100.0  111.0  False
# banana  300.0     300.0    NaN   True
# clock     NaN       NaN  333.0  False
# orange  200.0     200.0  222.0  False

# %%
df['anotherupper'] = df['one'][:1]

# %%
df
# Out:
#           one  copy_one    two   flag  anotherupper
# apple   100.0     100.0  111.0  False         100.0
# banana  300.0     300.0    NaN   True           NaN
# clock     NaN       NaN  333.0  False           NaN
# orange  200.0     200.0  222.0  False           NaN

# %% [markdown]
# ### Reading CSV

# %%
train = pd.read_csv('train.csv', sep=',')
print(type(train))
train.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
test = pd.read_csv('test.csv', sep=',')
print(type(test))
test.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
row_0 = train.iloc[0]

# %%
type(row_0)
# Out:
# pandas.core.series.Series

# %%
row_0
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
row_0['PassengerId']
# Out:
# 1

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.iloc[[0, 1, 4]]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# 4      0     373450   8.0500   NaN        S

# %%
train['PassengerId'].describe()
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# Name: PassengerId, dtype: float64

# %%
train['PassengerId'].max()
# Out:
# 891

# %%
train['Survived'].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
train['Embarked'].mode()
# Out:
# 0    S
# dtype: object

# %%
train.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
filter1 = train['PassengerId'] > 800
filter1.any()
# Out:
# True

# %%
type(filter1)
# Out:
# pandas.core.series.Series

# %%
movies = pd.read_csv('WATCHLIST.csv', sep=',')

# %%
movies
# Out:
#     Position      Const     Created    Modified  Description  \
# 0          1  tt2080374  2015-05-06  2015-05-06          NaN
# 1          2  tt1386697  2015-05-12  2015-05-12          NaN
# 2          3  tt3072482  2016-03-08  2016-03-08          NaN
# 3          4  tt3322312  2016-03-27  2016-03-27          NaN
# 4          5  tt0974015  2016-03-27  2016-03-27          NaN
# 5          6  tt0264464  2016-03-27  2016-03-27          NaN
# 6          7  tt1211837  2016-03-27  2016-03-27          NaN
# 7          8  tt3385516  2016-03-27  2016-03-27          NaN
# 8          9  tt3110958  2016-03-27  2016-03-27          NaN
# 9         10  tt2948356  2016-03-27  2016-03-27          NaN
# 10        11  tt3460252  2016-03-27  2016-03-27          NaN
# 11        12  tt4853102  2016-05-10  2016-05-10          NaN
# 12        13  tt1628841  2016-05-10  2016-05-10          NaN
# 13        14  tt3949660  2016-05-10  2016-05-10          NaN
# ...

# %%
movies.shape
# Out:
# (65, 17)

# %%
movies.isnull().any()
# Out:
# Position          False
# Const             False
# Created           False
# Modified          False
# Description        True
# Title             False
# URL               False
# Title Type        False
# IMDb Rating        True
# Runtime (mins)     True
# Year               True
# Genres            False
# Num Votes          True
# Release Date       True
# Directors          True
# Your Rating        True
# Date Rated         True
# dtype: bool

# %%
movies = movies.dropna(axis=1)

# %%
movies.isnull().any()
# Out:
# Position      False
# Const         False
# Created       False
# Modified      False
# Title         False
# URL           False
# Title Type    False
# Genres        False
# dtype: bool

# %%
movies.shape
# Out:
# (65, 8)

# %%
movies
# Out:
#     Position      Const     Created    Modified  \
# 0          1  tt2080374  2015-05-06  2015-05-06
# 1          2  tt1386697  2015-05-12  2015-05-12
# 2          3  tt3072482  2016-03-08  2016-03-08
# 3          4  tt3322312  2016-03-27  2016-03-27
# 4          5  tt0974015  2016-03-27  2016-03-27
# 5          6  tt0264464  2016-03-27  2016-03-27
# 6          7  tt1211837  2016-03-27  2016-03-27
# 7          8  tt3385516  2016-03-27  2016-03-27
# 8          9  tt3110958  2016-03-27  2016-03-27
# 9         10  tt2948356  2016-03-27  2016-03-27
# 10        11  tt3460252  2016-03-27  2016-03-27
# 11        12  tt4853102  2016-05-10  2016-05-10
# 12        13  tt1628841  2016-05-10  2016-05-10
# 13        14  tt3949660  2016-05-10  2016-05-10
# 14        15  tt4154756  2016-05-10  2016-05-10
# 15        16  tt3501632  2016-05-10  2016-05-10
# 16        17  tt5095030  2016-05-10  2016-05-10
# 17        18  tt4154796  2016-05-10  2016-05-10
# ...

# %%
df
# Out:
#           one  copy_one    two   flag  anotherupper
# apple   100.0     100.0  111.0  False         100.0
# banana  300.0     300.0    NaN   True           NaN
# clock     NaN       NaN  333.0  False           NaN
# orange  200.0     200.0  222.0  False           NaN

# %%
dsd = df.pop('anotherupper')

# %%
df.interpolate()
# Out:
#           one  copy_one    two   flag
# apple   100.0     100.0  111.0  False
# banana  300.0     300.0  222.0   True
# clock   250.0     250.0  333.0  False
# orange  200.0     200.0  222.0  False

# %%
flag = df.pop('flag')

# %%
df
# Out:
#           one  copy_one    two
# apple   100.0     100.0  111.0
# banana  300.0     300.0    NaN
# clock     NaN       NaN  333.0
# orange  200.0     200.0  222.0

# %%
df = df.interpolate()

# %%
df
# Out:
#           one  copy_one    two
# apple   100.0     100.0  111.0
# banana  300.0     300.0  222.0
# clock   250.0     250.0  333.0
# orange  200.0     200.0  222.0

# %%
df.plot.bar()

# %%
df
# Out:
#           one  copy_one    two
# apple   100.0     100.0  111.0
# banana  300.0     300.0  222.0
# clock   250.0     250.0  333.0
# orange  200.0     200.0  222.0

# %%
# %matplotlib inline

# %%
df.plot.box()

# %%
df
# Out:
#           one  copy_one    two
# apple   100.0     100.0  111.0
# banana  300.0     300.0  222.0
# clock   250.0     250.0  333.0
# orange  200.0     200.0  222.0

# %%
df.boxplot()

# %%
df.plot.hist()

# %%
df.plot()

# %%
movies.head()
# Out:
#    Position      Const     Created    Modified           Title  \
# 0         1  tt2080374  2015-05-06  2015-05-06      Steve Jobs
# 1         2  tt1386697  2015-05-12  2015-05-12   Suicide Squad
# 2         3  tt3072482  2016-03-08  2016-03-08  Hardcore Henry
# 3         4  tt3322312  2016-03-27  2016-03-27       Daredevil
# 4         5  tt0974015  2016-03-27  2016-03-27  Justice League
#
#                                      URL Title Type  \
# 0  https://www.imdb.com/title/tt2080374/      movie
# 1  https://www.imdb.com/title/tt1386697/      movie
# 2  https://www.imdb.com/title/tt3072482/      movie
# 3  https://www.imdb.com/title/tt3322312/   tvSeries
# 4  https://www.imdb.com/title/tt0974015/      movie
#
#                                    Genres
# 0                        Biography, Drama
# 1      Action, Adventure, Fantasy, Sci-Fi
# 2     Action, Adventure, Sci-Fi, Thriller
# 3  Action, Crime, Drama, Sci-Fi, Thriller
# 4      Action, Adventure, Fantasy, Sci-Fi

# %%
movies['Position'].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Position, dtype: int64

# %%
movies[['Position', 'Const']].head()
# Out:
#    Position      Const
# 0         1  tt2080374
# 1         2  tt1386697
# 2         3  tt3072482
# 3         4  tt3322312
# 4         5  tt0974015

# %%
movies = pd.read_csv('WATCHLIST.csv', sep=',')

# %%
movies.head()
# Out:
#    Position      Const     Created    Modified  Description           Title  \
# 0         1  tt2080374  2015-05-06  2015-05-06          NaN      Steve Jobs
# 1         2  tt1386697  2015-05-12  2015-05-12          NaN   Suicide Squad
# 2         3  tt3072482  2016-03-08  2016-03-08          NaN  Hardcore Henry
# 3         4  tt3322312  2016-03-27  2016-03-27          NaN       Daredevil
# 4         5  tt0974015  2016-03-27  2016-03-27          NaN  Justice League
#
#                                      URL Title Type  IMDb Rating  \
# 0  https://www.imdb.com/title/tt2080374/      movie          7.2
# 1  https://www.imdb.com/title/tt1386697/      movie          6.1
# 2  https://www.imdb.com/title/tt3072482/      movie          6.7
# 3  https://www.imdb.com/title/tt3322312/   tvSeries          8.7
# 4  https://www.imdb.com/title/tt0974015/      movie          6.7
#
#    Runtime (mins)    Year                                  Genres  Num Votes  \
# ...

# %%
movies.fillna(value=5)
# Out:
#     Position      Const     Created    Modified  Description  \
# 0          1  tt2080374  2015-05-06  2015-05-06          5.0
# 1          2  tt1386697  2015-05-12  2015-05-12          5.0
# 2          3  tt3072482  2016-03-08  2016-03-08          5.0
# 3          4  tt3322312  2016-03-27  2016-03-27          5.0
# 4          5  tt0974015  2016-03-27  2016-03-27          5.0
# 5          6  tt0264464  2016-03-27  2016-03-27          5.0
# 6          7  tt1211837  2016-03-27  2016-03-27          5.0
# 7          8  tt3385516  2016-03-27  2016-03-27          5.0
# 8          9  tt3110958  2016-03-27  2016-03-27          5.0
# 9         10  tt2948356  2016-03-27  2016-03-27          5.0
# 10        11  tt3460252  2016-03-27  2016-03-27          5.0
# 11        12  tt4853102  2016-05-10  2016-05-10          5.0
# 12        13  tt1628841  2016-05-10  2016-05-10          5.0
# 13        14  tt3949660  2016-05-10  2016-05-10          5.0
# ...

# %%
highRate = movies['Your Rating'] >= 4.0

# %%
highRate.value_counts()
# Out:
# False    62
# True      3
# Name: Your Rating, dtype: int64
